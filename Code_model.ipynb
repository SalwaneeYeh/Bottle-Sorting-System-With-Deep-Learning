# %% [markdown]
# <a href="https://colab.research.google.com/github/SalwaneeYeh/Bottle-Sorting-System-With-Deep-Learning/blob/main/Code_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_path = "/content/sort-bottleuse.v1-use.folder.zip"
extract_path = "/content/dataset"

# Create the extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # This will attempt to extract all files.
    # If there's an error, it will stop the program and show the error.
    zip_ref.extractall(extract_path)

print("✅ แตกไฟล์เรียบร้อย")
# List files in the extracted directory to verify
print("ไฟล์ทั้งหมดใน dataset:", os.listdir(extract_path))
# Out:
# ✅ แตกไฟล์เรียบร้อย
# ไฟล์ทั้งหมดใน dataset: ['README.dataset.txt', 'README.roboflow.txt', 'train', 'valid', 'test']

# %%
import os
print(os.listdir("/content/dataset"))
# Out:
# ['README.dataset.txt', 'README.roboflow.txt', 'train', 'valid', 'test']

# %% [markdown]
# โค้ดสมบูรณ์

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# === 1. CONFIG ===
img_size = (224, 224)
batch_size = 32
epochs = 30
learning_rate = 0.0001
dataset_path = "/content/dataset"

# === 2. DATA LOADING ===
train_dir = os.path.join(dataset_path, 'train')
val_dir = os.path.join(dataset_path, 'valid')

# Data Augmentation เฉพาะชุด train
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

# Load dataset
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

# === 3. MODEL CREATION ===
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=img_size + (3,))
base_model.trainable = False  # Freeze base model

# Add custom head on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# === 4. COMPILE ===
model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# === ✅ ADD CHECKPOINT ===
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'best_model_epoch30-00001.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# === 5. TRAINING ===
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    callbacks=[checkpoint]  # ✅ เพิ่ม callback
)

# === 6. SAVE MODEL ===
model.save("mobilenetv2_final_model.h5")
print("✅ บันทึกโมเดลเป็น mobilenetv2_final_model1-00001.h5 เรียบร้อยแล้ว")

# === 7. PLOT GRAPH ===
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('training_results.png')
print("✅ บันทึกกราฟผลลัพธ์ไว้ที่ training_results.png แล้วเรียบร้อย")
plt.show()

# export labels.txt
class_indices = train_generator.class_indices
sorted_classes = sorted(class_indices.items(), key=lambda x: x[1])  # sort ตาม index
labels = [cls[0] for cls in sorted_classes]

with open("labels.txt", "w") as f:
    for label in labels:
        f.write(label + "\n")

print("✅ สร้าง labels.txt เรียบร้อยแล้ว:", labels)
# Out:
# Found 1728 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3276 - loss: 1.4563
# Epoch 1: val_accuracy improved from -inf to 0.68056, saving model to best_model_epoch30-00001.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %% [markdown]
# โค้ดเดิม ก่อนมี export .txt

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# === 1. CONFIG ===
img_size = (640, 640)
batch_size = 32
epochs = 30
learning_rate = 0.0001
dataset_path = "real-Bottle2.v10i.folder"

# === 2. DATA LOADING ===
train_dir = os.path.join(dataset_path, 'train')
val_dir = os.path.join(dataset_path, 'valid')

# Data Augmentation เฉพาะชุด train
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

# Load dataset
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

# === 3. MODEL CREATION ===
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=img_size + (3,))
base_model.trainable = False  # Freeze base model

# Add custom head on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# === 4. COMPILE ===
model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# === ✅ ADD CHECKPOINT ===
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'best_model_epoch30.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# === 5. TRAINING ===
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    callbacks=[checkpoint]  # ✅ เพิ่ม callback
)

# === 6. SAVE MODEL ===
model.save("mobilenetv2_final_model1.h5")
print("✅ บันทึกโมเดลเป็น mobilenetv2_final_model1.h5 เรียบร้อยแล้ว")

# === 7. PLOT GRAPH ===
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('training_results.png')
print("✅ บันทึกกราฟผลลัพธ์ไว้ที่ training_results.png แล้วเรียบร้อย")
plt.show()

# %% [markdown]
# object detect

# %% [markdown]
# 📝 โค้ด (MobileNetV2, 224×224, 2 Stage Transfer Learning)

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# === 1. CONFIG ===
img_size = (224, 224)   # ✅ baseline input
batch_size = 32
epochs_stage1 = 20      # เทรนเฉพาะ classifier
epochs_stage2 = 10      # fine-tune base model
learning_rate_stage1 = 0.0001
learning_rate_stage2 = 1e-5
dataset_path = "/content/dataset"

# === 2. DATA LOADING ===
train_dir = os.path.join(dataset_path, 'train')
val_dir = os.path.join(dataset_path, 'valid')

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

# === 3. MODEL CREATION ===
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=img_size + (3,))
base_model.trainable = False  # Freeze base model (Stage 1)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# === 4. COMPILE ===
model.compile(
    optimizer=Adam(learning_rate=learning_rate_stage1),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
checkpoint = ModelCheckpoint(
    'best_model_stage1.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# === 5. TRAINING STAGE 1 ===
print("\n=== 🚀 Stage 1: Train เฉพาะ Classifier Layers ===\n")
history_stage1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_stage1,
    callbacks=[checkpoint, early_stop]
)

# === 6. FINE-TUNE STAGE 2 ===
print("\n=== 🔧 Stage 2: Fine-tune MobileNetV2 (บาง layers) ===\n")

# Unfreeze บาง layer ท้ายสุด
for layer in base_model.layers[-30:]:
    layer.trainable = True

# Compile ใหม่ด้วย learning rate เล็ก
model.compile(
    optimizer=Adam(learning_rate=learning_rate_stage2),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

checkpoint2 = ModelCheckpoint(
    'best_model_stage2.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

history_stage2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_stage2,
    callbacks=[checkpoint2, early_stop]
)

# === 7. SAVE MODEL ===
model.save("mobilenetv2_final_finetuned_224.h5")
print("✅ บันทึกโมเดลเป็น mobilenetv2_final_finetuned_224.h5 เรียบร้อยแล้ว")

# === 8. PLOT GRAPH ===
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history_stage1.history['accuracy'] + history_stage2.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history_stage1.history['val_accuracy'] + history_stage2.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('Accuracy over Epochs (Stage1+Stage2)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history_stage1.history['loss'] + history_stage2.history['loss'], label='Train Loss', marker='o')
plt.plot(history_stage1.history['val_loss'] + history_stage2.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss over Epochs (Stage1+Stage2)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('training_results_stages_224.png')
print("✅ บันทึกกราฟผลลัพธ์ไว้ที่ training_results_stages_224.png แล้วเรียบร้อย")
plt.show()

# export labels.txt
class_indices = train_generator.class_indices
sorted_classes = sorted(class_indices.items(), key=lambda x: x[1])
labels = [cls[0] for cls in sorted_classes]

with open("labels.txt", "w") as f:
    for label in labels:
        f.write(label + "\n")

print("✅ สร้าง labels.txt เรียบร้อยแล้ว:", labels)

# %% [markdown]
# 📝 โค้ด (MobileNetV2, 224×224, 2 Stage Transfer Learning)

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# === 1. CONFIG ===
img_size = (224, 224)
batch_size = 32
epochs_stage1 = 20   # เทรนเฉพาะ classifier
epochs_stage2 = 10   # fine-tune base model
learning_rate_stage1 = 0.00001
learning_rate_stage2 = 1e-5
dataset_path = "/content/dataset"

# === 2. DATA LOADING ===
train_dir = os.path.join(dataset_path, 'train')
val_dir = os.path.join(dataset_path, 'valid')

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

# === 3. MODEL CREATION ===
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=img_size + (3,))
base_model.trainable = False  # Freeze base model (Stage 1)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# === 4. COMPILE ===
model.compile(
    optimizer=Adam(learning_rate=learning_rate_stage1),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
checkpoint = ModelCheckpoint(
    'best_model_stage1-00001.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# === 5. TRAINING STAGE 1 ===
print("\n=== 🚀 Stage 1: Train เฉพาะ Classifier Layers ===\n")
history_stage1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_stage1,
    callbacks=[checkpoint, early_stop]
)

# === 6. FINE-TUNE STAGE 2 ===
print("\n=== 🔧 Stage 2: Fine-tune MobileNetV2 (บาง layers) ===\n")

# Unfreeze บาง layer ท้ายสุด
for layer in base_model.layers[-30:]:
    layer.trainable = True

# Compile ใหม่ด้วย learning rate เล็ก
model.compile(
    optimizer=Adam(learning_rate=learning_rate_stage2),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

checkpoint2 = ModelCheckpoint(
    'best_model_stage2-00001.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

history_stage2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_stage2,
    callbacks=[checkpoint2, early_stop]
)

# === 7. SAVE MODEL ===
model.save("mobilenetv2_final_finetuned00001.h5")
print("✅ บันทึกโมเดลเป็น mobilenetv2_final_finetuned.h5 เรียบร้อยแล้ว")

# === 8. PLOT GRAPH ===
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history_stage1.history['accuracy'] + history_stage2.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history_stage1.history['val_accuracy'] + history_stage2.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('Accuracy over Epochs (Stage1+Stage2)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history_stage1.history['loss'] + history_stage2.history['loss'], label='Train Loss', marker='o')
plt.plot(history_stage1.history['val_loss'] + history_stage2.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss over Epochs (Stage1+Stage2)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('training_results_stages00001.png')
print("✅ บันทึกกราฟผลลัพธ์ไว้ที่ training_results_stages.png แล้วเรียบร้อย")
plt.show()

# export labels.txt
class_indices = train_generator.class_indices
sorted_classes = sorted(class_indices.items(), key=lambda x: x[1])
labels = [cls[0] for cls in sorted_classes]

with open("labels00001.txt", "w") as f:
    for label in labels:
        f.write(label + "\n")

print("✅ สร้าง labels0001/2.txt เรียบร้อยแล้ว:", labels)
# Out:
# Found 432 images belonging to 4 classes.
# Found 18 images belonging to 4 classes.
#
# === 🚀 Stage 1: Train เฉพาะ Classifier Layers ===
#
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2504 - loss: 2.1270
# Epoch 1: val_accuracy improved from -inf to 0.05556, saving model to best_model_stage1-00001.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.2499 - loss: 2.1237 - val_accuracy: 0.0556 - val_loss: 1.8089
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2653 - loss: 1.7568
# Epoch 2: val_accuracy improved from 0.05556 to 0.11111, saving model to best_model_stage1-00001.h5
# ...
